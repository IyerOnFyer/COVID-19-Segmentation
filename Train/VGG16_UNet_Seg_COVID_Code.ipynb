# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd drive/My Drive/keras-u-net-master
# Out:
# /content/drive/My Drive/keras-u-net-master

# %%
from __future__ import print_function

import os
import numpy as np

from skimage.io import imsave, imread
from PIL import Image
data_path = 'data/'

image_rows = 512
image_cols = 512


def create_train_data():
    train_data_path = os.path.join(data_path, 'train/Image PP/')
    train_data_Label_path = os.path.join(data_path, 'train/Label/')
    images = os.listdir(train_data_path)
    total = len(images)

    imgs = np.ndarray((total, image_rows, image_cols), dtype=np.uint8)
    imgs_mask = np.ndarray((total, image_rows, image_cols), dtype=np.uint8)

    i = 0
    print('-'*30)
    print('Creating training images...')
    print('-'*30)
    for image_name in images:
        img = imread(os.path.join(train_data_path, image_name), as_gray=True)
        img_mask = imread(os.path.join(train_data_Label_path, image_name), as_gray=True)

        img = np.array([img])
        img_mask = np.array([img_mask])

        imgs[i] = img
        imgs_mask[i] = img_mask

        if i % 50 == 0:
            print('Done: {0}/{1} images'.format(i, total))
        i += 1
    print('Loading done.')

    np.save('imgs_train.npy', imgs)
    np.save('imgs_mask_train.npy', imgs_mask)
    print('Saving to .npy files done.')


def load_train_data():
    imgs_train = np.load('imgs_train.npy')
    imgs_mask_train = np.load('imgs_mask_train.npy')
    return imgs_train, imgs_mask_train


def create_test_data():
    train_data_path = os.path.join(data_path, 'test/Image PP')
    images = os.listdir(train_data_path)
    total = len(images)

    imgs = np.ndarray((total, image_rows, image_cols), dtype=np.uint8)
    imgs_id = np.ndarray((total, ), dtype=np.int32)

    i = 0
    print('-'*30)
    print('Creating test images...')
    print('-'*30)
    for image_name in images:
        img_id = int(image_name.split('.')[0])
        img = imread(os.path.join(train_data_path, image_name), as_gray=True)

        img = np.array([img])

        imgs[i] = img
        imgs_id[i] = img_id

        if i % 10 == 0:
            print('Done: {0}/{1} images'.format(i, total))
        i += 1
    print('Loading done.')

    np.save('imgs_test.npy', imgs)
    np.save('imgs_id_test.npy', imgs_id)
    print('Saving to .npy files done.')

def load_test_data():
    imgs_test = np.load('imgs_test.npy')
    imgs_id = np.load('imgs_id_test.npy')
    return imgs_test, imgs_id

if __name__ == '__main__':
    create_train_data()
    create_test_data()
# Out:
# ------------------------------
# Creating training images...
# ------------------------------
# Done: 0/150 images
# Done: 50/150 images
# Done: 100/150 images
# Loading done.
# Saving to .npy files done.
# ------------------------------
# Creating test images...
# ------------------------------
# Done: 0/60 images
# Done: 10/60 images
# Done: 20/60 images
# Done: 30/60 images
# Done: 40/60 images
# Done: 50/60 images
# Loading done.
# Saving to .npy files done.

# %%
from __future__ import print_function
import tensorflow as tf
import os
from skimage.transform import resize
from skimage.io import imsave
import numpy as np
from keras.models import Model
from keras.layers import Input, concatenate, Conv2D, MaxPooling2D, Conv2DTranspose, Activation
from keras.layers import BatchNormalization
from keras.optimizers import Adam
from keras import backend as K
from keras import losses,metrics
from keras.callbacks import ModelCheckpoint
														  
from data_preparation import load_train_data, load_test_data


smooth = 1.


def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)


def dice_coef_loss(y_true, y_pred):
    return dice_coef(y_true, y_pred)


img_w, img_h = (256, 256) 
                
def unet(num_classes, input_shape, lr_init, lr_decay, vgg_weight_path=None):
    img_input = Input(input_shape)

    # Block 1
    x = Conv2D(64, (3, 3), padding='same', name='block1_conv1')(img_input)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(64, (3, 3), padding='same', name='block1_conv2')(x)
    x = BatchNormalization()(x)
    block_1_out = Activation('relu')(x)

    x = MaxPooling2D()(block_1_out)

    # Block 2
    x = Conv2D(128, (3, 3), padding='same', name='block2_conv1')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(128, (3, 3), padding='same', name='block2_conv2')(x)
    x = BatchNormalization()(x)
    block_2_out = Activation('relu')(x)

    x = MaxPooling2D()(block_2_out)

    # Block 3
    x = Conv2D(256, (3, 3), padding='same', name='block3_conv1')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(256, (3, 3), padding='same', name='block3_conv2')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(256, (3, 3), padding='same', name='block3_conv3')(x)
    x = BatchNormalization()(x)
    block_3_out = Activation('relu')(x)

    x = MaxPooling2D()(block_3_out)

    # Block 4
    x = Conv2D(512, (3, 3), padding='same', name='block4_conv1')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(512, (3, 3), padding='same', name='block4_conv2')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(512, (3, 3), padding='same', name='block4_conv3')(x)
    x = BatchNormalization()(x)
    block_4_out = Activation('relu')(x)

    x = MaxPooling2D()(block_4_out)

    # Block 5
    x = Conv2D(512, (3, 3), padding='same', name='block5_conv1')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(512, (3, 3), padding='same', name='block5_conv2')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(512, (3, 3), padding='same', name='block5_conv3')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    for_pretrained_weight = MaxPooling2D()(x)

    # Load pretrained weights.
    if vgg_weight_path is not None:
        vgg16 = Model(img_input, for_pretrained_weight)
        vgg16.load_weights(vgg_weight_path, by_name=True)

    # UP 1
    x = Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = concatenate([x, block_4_out])
    x = Conv2D(512, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(512, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # UP 2
    x = Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = concatenate([x, block_3_out])
    x = Conv2D(256, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(256, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # UP 3
    x = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = concatenate([x, block_2_out])
    x = Conv2D(128, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(128, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # UP 4
    x = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = concatenate([x, block_1_out])
    x = Conv2D(64, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(64, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # last conv
    x = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

    model = Model(img_input, x)

    #model.compile(optimizer=Adam(lr=1e-5), loss='binary_crossentropy', metrics=[dice_coef,'acc', tf.keras.metrics.MeanIoU(num_classes=2),metrics.mae])
    #model.compile(optimizer=Adam(lr=1e-5), loss='binary_crossentropy', metrics=[metrics.binary_accuracy,keras_metrics.binary_precision(),keras_metrics.binary_recall()])
    #model.compile(optimizer=Adam(lr=1e-5), loss='binary_crossentropy', metrics=['accuracy'])
    model.compile(optimizer=Adam(lr=lr_init, decay=lr_decay),loss='binary_crossentropy',metrics=[dice_coef,'acc', tf.keras.metrics.MeanIoU(num_classes=2),metrics.mae])
    
    return model

def preprocess(imgs):
    imgs_p = np.ndarray((imgs.shape[0], img_w, img_h), dtype=np.uint8)
    for i in range(imgs.shape[0]):
        imgs_p[i] = resize(imgs[i], (img_h, img_w), preserve_range=True)

    imgs_p = imgs_p[..., np.newaxis]
    return imgs_p


def train_and_predict():
    print('Loading and preprocessing train data...')
    imgs_train, imgs_mask_train = load_train_data()

    imgs_train = preprocess(imgs_train)
    imgs_mask_train = preprocess(imgs_mask_train)

    imgs_train = imgs_train.astype('float32')
    mean = np.mean(imgs_train)  # mean for data centering
    std = np.std(imgs_train)  # std for data normalization

    imgs_train -= mean
    imgs_train /= std

    imgs_mask_train = imgs_mask_train.astype('float32')
    imgs_mask_train /= 255.  # scale masks to [0, 1]
    
    #model=unet(1,(512,512,1),1e-5,1e-4,'unet_weights_150_Img_VGG.h5')
    model=unet(1,(256,256,1),1e-5,1e-4)
    print(model.summary())
    
    model_checkpoint = ModelCheckpoint('unet_weights_150_Img_VGG.h5', monitor='val_loss', save_best_only=True)
    print('Fitting model...')
    hist=model.fit(imgs_train, imgs_mask_train, batch_size=16, nb_epoch=1000, verbose=1, shuffle=True,
              validation_split=0.2,
              callbacks=[model_checkpoint])

    imgs_test, imgs_id_test = load_test_data()
    imgs_test = preprocess(imgs_test)
    imgs_test = imgs_test.astype('float32')
    mean=np.mean(imgs_test)
    std=np.std(imgs_test)
    imgs_test -= mean
    imgs_test /= std

    model.load_weights('unet_weights_150_Img_VGG.h5')

    print('Predicting masks on test data...')

    imgs_mask_test = model.predict(imgs_test, verbose=1)
    np.save('imgs_mask_test.npy', imgs_mask_test)
    pred_dir = 'preds_VGG'

    if not os.path.exists(pred_dir):
      os.mkdir(pred_dir)

    for image, image_id in zip(imgs_mask_test, imgs_id_test):
      image = (image[:, :, 0] * 255.).astype(np.uint8)
      imsave(os.path.join(pred_dir, str(image_id) + '_pred.png'), image)
    
    import matplotlib.pyplot as plt
    import pickle
    model.load_weights('unet_weights_150_Img_VGG.h5')
    l_v=plt.plot(hist.history['loss'], color='b')
    vl_v=plt.plot(hist.history['val_loss'], color='r')
    plt.title('Loss Curve')
    pickle.dump(l_v, open('Loss_VGG.fig.pickle', 'wb')) # This is for Python 3 - py2 may need `file` instead of `open`
    pickle.dump(vl_v, open('Val_Loss_VGG.fig.pickle', 'wb')) # This is for Python 3 - py2 may need `file` instead of `open`
    plt.show()

    d_v=plt.plot(hist.history['dice_coef'], color='b')
    vd_v=plt.plot(hist.history['val_dice_coef'], color='r')
    plt.title('Dice Coefficient Curve')
    pickle.dump(d_v, open('Dice_VGG.fig.pickle', 'wb')) # This is for Python 3 - py2 may need `file` instead of `open`
    pickle.dump(vd_v, open('Val_Dice_VGG.fig.pickle', 'wb')) # This is for Python 3 - py2 may need `file` instead of `open`
    plt.show()

    a_v=plt.plot(hist.history['acc'], color='b')
    va_v=plt.plot(hist.history['val_acc'], color='r')
    pickle.dump(a_v, open('Acc_VGG.fig.pickle', 'wb')) # This is for Python 3 - py2 may need `file` instead of `open`
    pickle.dump(va_v, open('Val_Acc_VGG.fig.pickle', 'wb')) # This is for Python 3 - py2 may need `file` instead of `open`
    plt.title('Accuracy Curve')
    plt.show()

if __name__ == '__main__':
    train_and_predict()
# Out:
# Using TensorFlow backend.
# Loading and preprocessing train data...
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 256, 256, 1)  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 256, 256, 64) 640         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 256, 64) 256         block1_conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 256, 256, 64) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 256, 256, 64) 36928       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 256, 256, 64) 256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 256, 256, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 64) 0           activation_2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 128, 128, 128 73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128, 128, 128 512         block2_conv1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 128, 128, 128 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 128, 128, 128 147584      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 128, 128, 128 512         block2_conv2[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 128, 128, 128 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 128)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 64, 64, 256)  295168      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64, 64, 256)  1024        block3_conv1[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 64, 64, 256)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 64, 64, 256)  590080      activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 64, 64, 256)  1024        block3_conv2[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 64, 64, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 64, 64, 256)  590080      activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 64, 64, 256)  1024        block3_conv3[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 64, 64, 256)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 256)  0           activation_7[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 32, 32, 512)  1180160     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32, 32, 512)  2048        block4_conv1[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 32, 32, 512)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 32, 32, 512)  2359808     activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 32, 32, 512)  2048        block4_conv2[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 32, 32, 512)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 32, 32, 512)  2359808     activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 32, 32, 512)  2048        block4_conv3[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 32, 32, 512)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 16, 16, 512)  0           activation_10[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, 16, 16, 512)  2359808     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 512)  2048        block5_conv1[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 512)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, 16, 16, 512)  2359808     activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 512)  2048        block5_conv2[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 512)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, 16, 16, 512)  2359808     activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 512)  2048        block5_conv3[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 16, 16, 512)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 32, 32, 512)  1049088     activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 32, 32, 512)  2048        conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 32, 32, 512)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 1024) 0           activation_14[0][0]
#                                                                  activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 512)  4719104     concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 32, 32, 512)  2048        conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 32, 32, 512)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 512)  2359808     activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 32, 32, 512)  2048        conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 32, 32, 512)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 64, 64, 256)  524544      activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 64, 64, 256)  1024        conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 64, 64, 256)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 512)  0           activation_17[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 256)  1179904     concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 64, 64, 256)  1024        conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 64, 64, 256)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 256)  590080      activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 64, 64, 256)  1024        conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 64, 64, 256)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 128, 128, 128 131200      activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 128, 128, 128 512         conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 128, 128, 128 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 256 0           activation_20[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 128, 128, 128 295040      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 128, 128, 128 512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 128, 128, 128 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 128, 128, 128 147584      activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 128, 128, 128 512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 128, 128, 128 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 256, 256, 64) 32832       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 256, 256, 64) 256         conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 256, 256, 64) 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 256, 256, 128 0           activation_23[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 256, 256, 64) 73792       concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 256, 256, 64) 256         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 256, 256, 64) 0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 256, 256, 64) 36928       activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 256, 256, 64) 256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 256, 256, 64) 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 256, 256, 1)  577         activation_25[0][0]
# ==================================================================================================
# Total params: 25,882,433
# Trainable params: 25,868,225
# Non-trainable params: 14,208
# __________________________________________________________________________________________________
# None
# Fitting model...
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:211: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 120 samples, validate on 30 samples
# Epoch 1/1000
# 120/120 [==============================] - 23s 195ms/step - loss: 1.0472 - dice_coef: 0.1166 - acc: 0.2466 - mean_io_u: 0.4778 - mean_absolute_error: 0.5984 - val_loss: 0.7168 - val_dice_coef: 0.1248 - val_acc: 0.3471 - val_mean_io_u: 0.4761 - val_mean_absolute_error: 0.5075
# Epoch 2/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 1.0055 - dice_coef: 0.1241 - acc: 0.2588 - mean_io_u: 0.4759 - mean_absolute_error: 0.5871 - val_loss: 0.7079 - val_dice_coef: 0.1243 - val_acc: 0.4468 - val_mean_io_u: 0.4761 - val_mean_absolute_error: 0.5031
# Epoch 3/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.9621 - dice_coef: 0.1288 - acc: 0.2852 - mean_io_u: 0.4763 - mean_absolute_error: 0.5741 - val_loss: 0.7023 - val_dice_coef: 0.1240 - val_acc: 0.4932 - val_mean_io_u: 0.4761 - val_mean_absolute_error: 0.5003
# Epoch 4/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.9174 - dice_coef: 0.1308 - acc: 0.3217 - mean_io_u: 0.4762 - mean_absolute_error: 0.5596 - val_loss: 0.6989 - val_dice_coef: 0.1238 - val_acc: 0.5119 - val_mean_io_u: 0.4761 - val_mean_absolute_error: 0.4985
# Epoch 5/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.8723 - dice_coef: 0.1365 - acc: 0.3797 - mean_io_u: 0.4762 - mean_absolute_error: 0.5435 - val_loss: 0.6967 - val_dice_coef: 0.1237 - val_acc: 0.5179 - val_mean_io_u: 0.4761 - val_mean_absolute_error: 0.4973
# Epoch 6/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.8293 - dice_coef: 0.1337 - acc: 0.4436 - mean_io_u: 0.4761 - mean_absolute_error: 0.5274 - val_loss: 0.6956 - val_dice_coef: 0.1236 - val_acc: 0.5182 - val_mean_io_u: 0.4761 - val_mean_absolute_error: 0.4965
# Epoch 7/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0
1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.2308 - dice_coef: 0.2818 - acc: 0.9372 - mean_io_u: 0.4762 - mean_absolute_error: 0.1818 - val_loss: 0.3838 - val_dice_coef: 0.1326 - val_acc: 0.8923 - val_mean_io_u: 0.4762 - val_mean_absolute_error: 0.2663
# Epoch 79/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.2213 - dice_coef: 0.2831 - acc: 0.9415 - mean_io_u: 0.4762 - mean_absolute_error: 0.1759 - val_loss: 0.3501 - val_dice_coef: 0.1271 - val_acc: 0.8979 - val_mean_io_u: 0.4762 - val_mean_absolute_error: 0.2504
# Epoch 80/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.2135 - dice_coef: 0.3088 - acc: 0.9450 - mean_io_u: 0.4762 - mean_absolute_error: 0.1712 - val_loss: 0.3405 - val_dice_coef: 0.1354 - val_acc: 0.8927 - val_mean_io_u: 0.4762 - val_mean_absolute_error: 0.2463
# Epoch 81/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.2127 - dice_coef: 0.2997 - acc: 0.9438 - mean_io_u: 0.4762 - mean_absolute_error: 0.1700 - val_loss: 0.3131 - val_dice_coef: 0.1223 - val_acc: 0.9097 - val_mean_io_u: 0.4762 - val_mean_absolute_error: 0.2281
# Epoch 82/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.2094 - dice_coef: 0.3161 - acc: 0.9439 - mean_io_u: 0.4762 - mean_absolute_error: 0.1666 - val_loss: 0.3250 - val_dice_coef: 0.1279 - val_acc: 0.9005 - val_mean_io_u: 0.4762 - val_mean_absolute_error: 0.2356
# Epoch 83/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.2055 - dice_coef: 0.3129 - acc: 0.9470 - mean_io_u: 0.4762 - mean_absolute_error: 0.1650 - val_loss: 0.3042 - val_dice_coef: 0.1176 - val_acc: 0.9133 - val_mean_io_u: 0.4762 - val_mean_absolute_error: 0.2217
# Epoch 84/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.2026 - dice_coef: 0.3333 - acc: 0.9465 - mean_io_u: 0.4761 - mean_absolute_error: 0.1618 - val_loss: 0.3079 - val_dice_coef: 0.1215 - val_acc: 0.9094 - val_mean_io_u: 0.4762 - val_mean_absolute_error: 0.2241
# Epoch 85/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.2002 - dice_coef: 0.3347 - acc: 0.9485 - mean_io_u: 0.4762 - mean_absolute_error: 0.1610 - val_loss: 0.3013 - val_dice_coef: 0.1190 - val_acc: 0.9129 - val_mean_io_u: 0.4762 - val_mean_absolute_error: 0.2189
# Epoch 86/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.1980 - dice_coef: 0.3472 - acc: 0.9493 - mean_io_u: 0.4762 - mean_absolute_error: 0.1592 - val_loss: 0.3033 - val_dice_coef: 0.1196 - val_acc: 0.9093 - val_mean_io_u: 0.4762 - val_mean_absolute_error: 0.2186
# Epoch 87/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.1937 - dice_coef: 0.3439 - acc: 0.9499 - mean_io_u: 0.4761 - mean_absolute_error: 0.1559 - val_loss: 0.2953 - val_dice_coef: 0.1170 - val_acc: 0.9139 - val_mean_io_u: 0.4762 - val_mean_absolute_error: 0.2122
# Epoch 88/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.2057 - dice_coef: 0.3251 - acc: 0.9440 - mean_io_u: 0.4762 - mean_absolute_error: 0.1625 - val_loss: 0.2933 - val_dice_coef: 0.1154 - val_acc: 0.9145 - val_mean_io_u: 0.4762 - val_mean_absolute_error: 0.2102
# Epoch 89/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.1983 - dice_coef: 0.3439 - acc: 0.9463 - mean_io_u: 0.4762 - mean_absolute_error: 0.1571 - val_loss: 0.2978 - val_dice_coef: 0.1145 - val_acc: 0.9124 - val_mean_io_u: 0.4762 - val_mean_absolute_error: 0.2122
# Epoch 90/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.1918 - dice_coef: 0.3553 - acc: 0.9495 - mean_io_u: 0.4762 - mean_absolute_error: 0.1537 - val_loss: 0.2976 - val_dice_coef: 0.1170 - val_acc: 0.9104 - val_mean_io_u: 0.4762 - val_mean_absolute_error: 0.2119
# Epoch 91/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.1873 - dice_coef: 0.3679 - acc: 0.9512 - mean_io_u: 0.4762 - mean_absolute_error: 0.1508 - val_loss: 0.2954 - val_dice_coef: 0.1118 - val_acc: 0.9098 - val_mean_io_u: 0.4762 - val_mean_absolute_error: 0.2082
# Epoch 92/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.
- val_mean_io_u: 0.4763 - val_mean_absolute_error: 0.0839
# Epoch 967/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0155 - dice_coef: 0.9191 - acc: 0.9684 - mean_io_u: 0.4763 - mean_absolute_error: 0.0072 - val_loss: 0.4104 - val_dice_coef: 0.0523 - val_acc: 0.9113 - val_mean_io_u: 0.4763 - val_mean_absolute_error: 0.0816
# Epoch 968/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0162 - dice_coef: 0.9198 - acc: 0.9683 - mean_io_u: 0.4763 - mean_absolute_error: 0.0074 - val_loss: 0.4115 - val_dice_coef: 0.0523 - val_acc: 0.9102 - val_mean_io_u: 0.4763 - val_mean_absolute_error: 0.0830
# Epoch 969/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0153 - dice_coef: 0.9227 - acc: 0.9684 - mean_io_u: 0.4763 - mean_absolute_error: 0.0071 - val_loss: 0.4146 - val_dice_coef: 0.0725 - val_acc: 0.9051 - val_mean_io_u: 0.4763 - val_mean_absolute_error: 0.0883
# Epoch 970/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0158 - dice_coef: 0.9229 - acc: 0.9684 - mean_io_u: 0.4763 - mean_absolute_error: 0.0073 - val_loss: 0.4127 - val_dice_coef: 0.0576 - val_acc: 0.9101 - val_mean_io_u: 0.4763 - val_mean_absolute_error: 0.0827
# Epoch 971/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0154 - dice_coef: 0.9231 - acc: 0.9684 - mean_io_u: 0.4763 - mean_absolute_error: 0.0072 - val_loss: 0.4145 - val_dice_coef: 0.0480 - val_acc: 0.9112 - val_mean_io_u: 0.4763 - val_mean_absolute_error: 0.0817
# Epoch 972/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0162 - dice_coef: 0.9152 - acc: 0.9684 - mean_io_u: 0.4763 - mean_absolute_error: 0.0076 - val_loss: 0.4132 - val_dice_coef: 0.0546 - val_acc: 0.9109 - val_mean_io_u: 0.4764 - val_mean_absolute_error: 0.0817
# Epoch 973/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0155 - dice_coef: 0.9220 - acc: 0.9684 - mean_io_u: 0.4764 - mean_absolute_error: 0.0072 - val_loss: 0.4116 - val_dice_coef: 0.0589 - val_acc: 0.9099 - val_mean_io_u: 0.4764 - val_mean_absolute_error: 0.0832
# Epoch 974/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0155 - dice_coef: 0.9146 - acc: 0.9684 - mean_io_u: 0.4764 - mean_absolute_error: 0.0072 - val_loss: 0.4090 - val_dice_coef: 0.0717 - val_acc: 0.9078 - val_mean_io_u: 0.4764 - val_mean_absolute_error: 0.0855
# Epoch 975/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0151 - dice_coef: 0.9226 - acc: 0.9684 - mean_io_u: 0.4764 - mean_absolute_error: 0.0069 - val_loss: 0.4097 - val_dice_coef: 0.0570 - val_acc: 0.9109 - val_mean_io_u: 0.4764 - val_mean_absolute_error: 0.0821
# Epoch 976/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0158 - dice_coef: 0.9223 - acc: 0.9684 - mean_io_u: 0.4764 - mean_absolute_error: 0.0073 - val_loss: 0.4108 - val_dice_coef: 0.0599 - val_acc: 0.9096 - val_mean_io_u: 0.4764 - val_mean_absolute_error: 0.0836
# Epoch 977/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0159 - dice_coef: 0.9219 - acc: 0.9684 - mean_io_u: 0.4764 - mean_absolute_error: 0.0074 - val_loss: 0.4086 - val_dice_coef: 0.0716 - val_acc: 0.9081 - val_mean_io_u: 0.4764 - val_mean_absolute_error: 0.0849
# Epoch 978/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0155 - dice_coef: 0.9224 - acc: 0.9684 - mean_io_u: 0.4764 - mean_absolute_error: 0.0072 - val_loss: 0.4094 - val_dice_coef: 0.0609 - val_acc: 0.9096 - val_mean_io_u: 0.4764 - val_mean_absolute_error: 0.0835
# Epoch 979/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0152 - dice_coef: 0.9255 - acc: 0.9684 - mean_io_u: 0.4764 - mean_absolute_error: 0.0070 - val_loss: 0.4110 - val_dice_coef: 0.0707 - val_acc: 0.9072 - val_mean_io_u: 0.4764 - val_mean_absolute_error: 0.0860
# Epoch 980/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0173 - dice_coef: 0.9157 - acc: 0.9681 - mean_io_u: 0.4764 - mean_absolute_error: 0.0080 - val_loss: 0.4141 - val_dice_coef: 0.0447 - val_acc: 0.9124 - val_mean_io_u: 0.4764 - val_mean_absolute_error: 0.0802
# Epoch 981/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0164 - dice_coef: 0.9157 - acc: 0.9684 - mean_io_u: 0.4764 - mean_absolute_error: 0.0077 - val_loss: 0.4097 - val_dice_coef: 0.0605 - val_acc: 0.9104 - val_mean_io_u: 0.4764 - val_mean_absolute_error: 0.0824
# Epoch 982/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0148 - dice_coef: 0.9233 - acc: 0.9685 - mean_io_u: 0.4764 - mean_absolute_error: 0.0067 - val_loss: 0.4131 - val_dice_coef: 0.0593 - val_acc: 0.9099 - val_mean_io_u: 0.4764 - val_mean_absolute_error: 0.0830
# Epoch 983/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0159 - dice_coef: 0.9208 - acc: 0.9684 - mean_io_u: 0.4764 - mean_absolute_error: 0.0074 - val_loss: 0.4103 - val_dice_coef: 0.0671 - val_acc: 0.9089 - val_mean_io_u: 0.4764 - val_mean_absolute_error: 0.0841
# Epoch 984/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0151 - dice_coef: 0.9212 - acc: 0.9684 - mean_io_u: 0.4764 - mean_absolute_error: 0.0069 - val_loss: 0.4121 - val_dice_coef: 0.0598 - val_acc: 0.9102 - val_mean_io_u: 0.4764 - val_mean_absolute_error: 0.0827
# Epoch 985/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0155 - dice_coef: 0.9211 - acc: 0.9684 - mean_io_u: 0.4764 - mean_absolute_error: 0.0071 - val_loss: 0.4122 - val_dice_coef: 0.0641 - val_acc: 0.9090 - val_mean_io_u: 0.4764 - val_mean_absolute_error: 0.0840
# Epoch 986/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0150 - dice_coef: 0.9251 - acc: 0.9684 - mean_io_u: 0.4764 - mean_absolute_error: 0.0068 - val_loss: 0.4138 - val_dice_coef: 0.0637 - val_acc: 0.9091 - val_mean_io_u: 0.4764 - val_mean_absolute_error: 0.0837
# Epoch 987/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0146 - dice_coef: 0.9251 - acc: 0.9684 - mean_io_u: 0.4764 - mean_absolute_error: 0.0066 - val_loss: 0.4120 - val_dice_coef: 0.0626 - val_acc: 0.9093 - val_mean_io_u: 0.4764 - val_mean_absolute_error: 0.0836
# Epoch 988/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0156 - dice_coef: 0.9249 - acc: 0.9684 - mean_io_u: 0.4764 - mean_absolute_error: 0.0071 - val_loss: 0.4108 - val_dice_coef: 0.0772 - val_acc: 0.9066 - val_mean_io_u: 0.4764 - val_mean_absolute_error: 0.0865
# Epoch 989/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0146 - dice_coef: 0.9244 - acc: 0.9684 - mean_io_u: 0.4764 - mean_absolute_error: 0.0065 - val_loss: 0.4128 - val_dice_coef: 0.0608 - val_acc: 0.9094 - val_mean_io_u: 0.4764 - val_mean_absolute_error: 0.0836
# Epoch 990/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0153 - dice_coef: 0.9170 - acc: 0.9684 - mean_io_u: 0.4764 - mean_absolute_error: 0.0070 - val_loss: 0.4125 - val_dice_coef: 0.0587 - val_acc: 0.9100 - val_mean_io_u: 0.4764 - val_mean_absolute_error: 0.0829
# Epoch 991/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0150 - dice_coef: 0.9219 - acc: 0.9684 - mean_io_u: 0.4764 - mean_absolute_error: 0.0068 - val_loss: 0.4148 - val_dice_coef: 0.0641 - val_acc: 0.9086 - val_mean_io_u: 0.4764 - val_mean_absolute_error: 0.0844
# Epoch 992/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0150 - dice_coef: 0.9231 - acc: 0.9684 - mean_io_u: 0.4764 - mean_absolute_error: 0.0068 - val_loss: 0.4183 - val_dice_coef: 0.0515 - val_acc: 0.9105 - val_mean_io_u: 0.4764 - val_mean_absolute_error: 0.0822
# Epoch 993/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0160 - dice_coef: 0.9191 - acc: 0.9684 - mean_io_u: 0.4764 - mean_absolute_error: 0.0074 - val_loss: 0.4141 - val_dice_coef: 0.0629 - val_acc: 0.9090 - val_mean_io_u: 0.4764 - val_mean_absolute_error: 0.0840
# Epoch 994/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0143 - dice_coef: 0.9260 - acc: 0.9684 - mean_io_u: 0.4764 - mean_absolute_error: 0.0064 - val_loss: 0.4151 - val_dice_coef: 0.0559 - val_acc: 0.9102 - val_mean_io_u: 0.4764 - val_mean_absolute_error: 0.0827
# Epoch 995/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0149 - dice_coef: 0.9238 - acc: 0.9684 - mean_io_u: 0.4764 - mean_absolute_error: 0.0067 - val_loss: 0.4137 - val_dice_coef: 0.0550 - val_acc: 0.9107 - val_mean_io_u: 0.4764 - val_mean_absolute_error: 0.0822
# Epoch 996/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0146 - dice_coef: 0.9267 - acc: 0.9684 - mean_io_u: 0.4764 - mean_absolute_error: 0.0066 - val_loss: 0.4146 - val_dice_coef: 0.0548 - val_acc: 0.9107 - val_mean_io_u: 0.4764 - val_mean_absolute_error: 0.0820
# Epoch 997/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0153 - dice_coef: 0.9226 - acc: 0.9683 - mean_io_u: 0.4764 - mean_absolute_error: 0.0069 - val_loss: 0.4149 - val_dice_coef: 0.0651 - val_acc: 0.9087 - val_mean_io_u: 0.4764 - val_mean_absolute_error: 0.0840
# Epoch 998/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0153 - dice_coef: 0.9233 - acc: 0.9684 - mean_io_u: 0.4764 - mean_absolute_error: 0.0070 - val_loss: 0.4124 - val_dice_coef: 0.0680 - val_acc: 0.9085 - val_mean_io_u: 0.4764 - val_mean_absolute_error: 0.0845
# Epoch 999/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0154 - dice_coef: 0.9154 - acc: 0.9683 - mean_io_u: 0.4764 - mean_absolute_error: 0.0070 - val_loss: 0.4118 - val_dice_coef: 0.0606 - val_acc: 0.9100 - val_mean_io_u: 0.4764 - val_mean_absolute_error: 0.0829
# Epoch 1000/1000
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0151 - dice_coef: 0.9241 - acc: 0.9684 - mean_io_u: 0.4764 - mean_absolute_error: 0.0069 - val_loss: 0.4160 - val_dice_coef: 0.0474 - val_acc: 0.9120 - val_mean_io_u: 0.4764 - val_mean_absolute_error: 0.0807
# Predicting masks on test data...
# 60/60 [==============================] - 4s 74ms/step

# %%
# !pip install keras==2.2.2
# Out:
# Collecting keras==2.2.2
#   Downloading https://files.pythonhosted.org/packages/34/7d/b1dedde8af99bd82f20ed7e9697aac0597de3049b1f786aa2aac3b9bd4da/Keras-2.2.2-py2.py3-none-any.whl (299kB)
#      |████████████████████████████████| 307kB 2.8MB/s
# Collecting keras-preprocessing==1.0.2
#   Downloading https://files.pythonhosted.org/packages/71/26/1e778ebd737032749824d5cba7dbd3b0cf9234b87ab5ec79f5f0403ca7e9/Keras_Preprocessing-1.0.2-py2.py3-none-any.whl
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.2) (1.18.2)
# Collecting keras-applications==1.0.4
#   Downloading https://files.pythonhosted.org/packages/54/90/8f327deaa37a71caddb59b7b4aaa9d4b3e90c0e76f8c2d1572005278ddc5/Keras_Applications-1.0.4-py2.py3-none-any.whl (43kB)
#      |████████████████████████████████| 51kB 8.9MB/s
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.2) (1.4.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras==2.2.2) (2.10.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras==2.2.2) (3.13)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.2) (1.12.0)
# ERROR: tensorflow 2.2.0rc3 has requirement keras-preprocessing>=1.1.0, but you'll have keras-preprocessing 1.0.2 which is incompatible.
# Installing collected packages: keras-preprocessing, keras-applications, keras
#   Found existing installation: Keras-Preprocessing 1.1.0
#     Uninstalling Keras-Preprocessing-1.1.0:
#       Successfully uninstalled Keras-Preprocessing-1.1.0
#   Found existing installation: Keras-Applications 1.0.8
#     Uninstalling Keras-Applications-1.0.8:
#       Successfully uninstalled Keras-Applications-1.0.8
#   Found existing installation: Keras 2.3.1
#     Uninstalling Keras-2.3.1:
#       Successfully uninstalled Keras-2.3.1
# Successfully installed keras-2.2.2 keras-applications-1.0.4 keras-preprocessing-1.0.2

# %%
# !pip install keras_applications==1.0.7
# !pip install tensorflow==1.14
# Out:
# Requirement already satisfied: keras_applications==1.0.7 in /usr/local/lib/python3.6/dist-packages (1.0.7)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras_applications==1.0.7) (2.10.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras_applications==1.0.7) (1.18.2)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py->keras_applications==1.0.7) (1.12.0)
# Collecting tensorflow==1.14
#   Downloading https://files.pythonhosted.org/packages/de/f0/96fb2e0412ae9692dbf400e5b04432885f677ad6241c088ccc5fe7724d69/tensorflow-1.14.0-cp36-cp36m-manylinux1_x86_64.whl (109.2MB)
#      |████████████████████████████████| 109.2MB 28kB/s
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (0.8.1)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (0.3.3)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (1.18.2)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (0.9.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (0.2.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (3.10.0)
# Collecting tensorboard<1.15.0,>=1.14.0
#   Downloading https://files.pythonhosted.org/packages/91/2d/2ed263449a078cd9c8a9ba50ebd50123adf1f8cfbea1492f9084169b89d9/tensorboard-1.14.0-py3-none-any.whl (3.1MB)
#      |████████████████████████████████| 3.2MB 50.5MB/s
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (1.1.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (1.12.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (0.34.2)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (1.0.7)
# Collecting keras-preprocessing>=1.0.5
#   Downloading https://files.pythonhosted.org/packages/28/6a/8c1f62c37212d9fc441a7e26736df51ce6f0e38455816445471f10da4f0a/Keras_Preprocessing-1.1.0-py2.py3-none-any.whl (41kB)
#      |████████████████████████████████| 51kB 7.5MB/s
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (1.12.1)
# Collecting tensorflow-estimator<1.15.0rc0,>=1.14.0rc0
#   Downloading https://files.pythonhosted.org/packages/3c/d5/21860a5b11caf0678fbc8319341b0ae21a07156911132e0e71bffed0510d/tensorflow_estimator-1.14.0-py2.py3-none-any.whl (488kB)
#      |████████████████████████████████| 491kB 57.7MB/s
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14) (1.28.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow==1.14) (46.1.3)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (3.2.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow==1.14) (2.10.0)
# ERROR: keras 2.2.2 has requirement keras-applications==1.0.4, but you'll have keras-applications 1.0.7 which is incompatible.
# ERROR: keras 2.2.2 has requirement keras-preprocessing==1.0.2, but you'll have keras-preprocessing 1.1.0 which is incompatible.
# Installing collected packages: tensorboard, keras-preprocessing, tensorflow-estimator, tensorflow
#   Found existing installation: tensorboard 2.2.1
#     Uninstalling tensorboard-2.2.1:
#       Successfully uninstalled tensorboard-2.2.1
#   Found existing installation: Keras-Preprocessing 1.0.2
#     Uninstalling Keras-Preprocessing-1.0.2:
#       Successfully uninstalled Keras-Preprocessing-1.0.2
#   Found existing installation: tensorflow-estimator 2.2.0
#     Uninstalling tensorflow-estimator-2.2.0:
#       Successfully uninstalled tensorflow-estimator-2.2.0
#   Found existing installation: tensorflow 2.2.0rc3
#     Uninstalling tensorflow-2.2.0rc3:
#       Successfully uninstalled tensorflow-2.2.0rc3
# Successfully installed keras-preprocessing-1.1.0 tensorboard-1.14.0 tensorflow-1.14.0 tensorflow-estimator-1.14.0

# %%
import keras_applications as K
print(K.__version__)
# Out:
# 1.0.8

# %%
import matplotlib.pyplot as plt

model.load_weights('unet_weights_150_Img.h5')
plt.plot(hist.history['loss'], color='b')
plt.plot(hist.history['val_loss'], color='r')
plt.show()

plt.plot(hist.history['dice_coef'], color='b')
plt.plot(hist.history['val_dice_coef'], color='r')
plt.show()

plt.plot(hist.history['acc'], color='b')
plt.plot(hist.history['val_acc'], color='r')
plt.show()

plt.plot(hist.history['mean_i_ou_7'], color='b')
plt.plot(hist.history['val_mean_i_ou_7'], color='r')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-d284c997b75e> in <module>()
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 model.load_weights('unet_weights_150_Img.h5')
#       4 plt.plot(hist.history['loss'], color='b')
#       5 plt.plot(hist.history['val_loss'], color='r')
#
# NameError: name 'model' is not defined
